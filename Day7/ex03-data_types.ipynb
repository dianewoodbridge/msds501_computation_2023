# %%
import numpy as np

# %% [markdown]
# ### For bootcamp, change the dtype to Python Object.

# %%
bootcamp = np.array(["Dine", "Shan"])

# %%
bootcamp.dtype
# Out:
# dtype('<U4')

# %%
bootcamp.astype('U20')
# Out:
# array(['Dine', 'Shan'], dtype='<U20')

# %%
np.concatenate((bootcamp, ["Someone_else"]), 0)
# Out:
# array(['Dine', 'Shan', 'Someone_else'], dtype='<U12')
