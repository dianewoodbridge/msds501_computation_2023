# %%
import csv
import pickle

# %%
file_name = "../Data/epa_air_quality.csv"
station_id = 60070008

# %%
def return_pickled_date_set(file_name, station_id):
    """
    Create a function called return_pickled_date_set() 
    which takes file_name (csv) and station_id (int).
    This function should return a pickled object including
    a set of first columns (date strings)
    """

# %%
return_pickled_date_set(file_name, station_id)
# Out:
# b'\x80\x04\x95\xa7\x08\x00\x00\x00\x00\x00\x00\x8f\x94(\x8c\n2020-07-31\x94\x8c\n2020-04-01\x94\x8c\n2020-03-03\x94\x8c\n2020-05-15\x94\x8c\n2020-01-08\x94\x8c\n2020-03-02\x94\x8c\n2020-07-09\x94\x8c\n2020-02-26\x94\x8c\n2020-04-23\x94\x8c\n2020-04-07\x94\x8c\n2020-05-25\x94\x8c\n2020-05-20\x94\x8c\n2020-01-20\x94\x8c\n2020-05-22\x94\x8c\n2020-06-19\x94\x8c\n2020-01-17\x94\x8c\n2020-02-07\x94\x8c\n2020-04-27\x94\x8c\n2020-02-10\x94\x8c\n2020-02-17\x94\x8c\n2020-03-16\x94\x8c\n2020-05-21\x94\x8c\n2020-02-22\x94\x8c\n2020-04-13\x94\x8c\n2020-07-18\x94\x8c\n2020-01-23\x94\x8c\n2020-03-01\x94\x8c\n2020-04-19\x94\x8c\n2020-05-10\x94\x8c\n2020-03-09\x94\x8c\n2020-02-16\x94\x8c\n2020-05-31\x94\x8c\n2020-01-11\x94\x8c\n2020-04-26\x94\x8c\n2020-02-19\x94\x8c\n2020-03-30\x94\x8c\n2020-05-11\x94\x8c\n2020-05-28\x94\x8c\n2020-07-24\x94\x8c\n2020-03-10\x94\x8c\n2020-02-03\x94\x8c\n2020-05-18\x94\x8c\n2020-05-03\x94\x8c\n2020-06-29\x94\x8c\n2020-01-12\x94\x8c\n2020-03-04\x94\x8c\n2020-01-22\x94\x8
# ...
